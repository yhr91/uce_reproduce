# %%
import scanpy as sc

# %% [markdown]
# # Tabula Sapiens

# %%
from scgraph import scGraph

# Initialize the graph analyzer
scgraph = scGraph(
    adata_path="export_data/new_tabula_all_zero_shot_lognorm.h5ad",   # Path to AnnData object
    batch_key="sample_id",                     # Column name for batch information
    label_key="cell_ontology_class",                 # Column name for cell type labels
    trim_rate=0.05,                        # Trim rate for robust mean calculation
    thres_batch=100,                       # Minimum number of cells per batch
    thres_celltype=10,                    # Minimum number of cells per cell type
    only_umap=False,                        # Only evaluate 2D embeddings (mostly umaps)
)

# Run the analysis, return a pandas dataframe
results = scgraph.main()
display(results)
# Save the results
#results.to_csv("embedding_evaluation_results_sample.csv")
# Out:
# Skipped cell type epithelial fate stem cell, due to < 10 cells
# Skipped cell type erythroid lineage cell, due to < 10 cells
# Skipped cell type mesenchymal cell, due to < 10 cells
# Skipped cell type t follicular helper cell, due to < 10 cells
# Skipped cell type follicle, due to < 10 cells
# Skipped cell type pancreatic d cell, due to < 10 cells
# Skipped cell type pancreatic pp cell, due to < 10 cells
# Skipped cell type retina horizontal cell, due to < 10 cells
# Skipped cell type retinal ganglion cell, due to < 10 cells
# Processing batches, calcualte centroids and pairwise distances
#   0%|          | 0/534 [00:00<?, ?it/s]
# Skipped batch TSP14_Thymus_NA_SS2_B134098_D102004, due to < 100 cells
# Skipped batch TSP6_Liver_NA_SS2_L144734_B114853, due to < 100 cells
# Skipped batch TSP14_Heart_NA_SS2_B134529_B133810, due to < 100 cells
# Skipped batch TSP2_Lung_ProxMedialDistal_SS2_B113373_B134458, due to < 100 cells
# Skipped batch TSP3_Eye_NoCornea_SS2_B114702_B133904, due to < 100 cells
# Skipped batch TSP10_Fat_MAT_SS2_B134171_B115063, due to < 100 cells
# Skipped batch TSP13_Bone_Marrow_VertebralBody_SS2_B133712_B134041, due to < 100 cells
# Skipped batch TSP14_Heart_NA_SS2_B133790_D101540, due to < 100 cells
# Skipped batch TSP6_Liver_NA_SS2_L144742_B133819, due to < 100 cells
# Skipped batch TSP7_Tongue_Posterior_SS2_B134144_B133911, due to < 100 cells
# Skipped batch TSP4_Mammary_NA_SS2_B112795_B134698, due to < 100 cells
# Skipped batch TSP2_Lung_Proximal_SS2_B113453_B133092, due to < 100 cells
# Skipped batch TSP6_Trachea_NA_SS2_B113448_B133907, due to < 100 cells
# Skipped batch TSP3_Eye_LacrimalGland_SS2_B114666_B133915, due to < 100 cells
# Skipped batch TSP2_Blood_NA_SS2_B113459_B133094, due to < 100 cells
# Skipped batch TSP2_Skin_Abdomen_SS2_B113705_B111656, due to < 100 cells
# Skipped batch TSP5_Eye_Whole_SS2_B112804_B104881, due to < 100 cells
# Skipped batch TSP4_Uterus_NA_SS2_B112797_B134702, due to < 100 cells
# Skipped batch TSP13_Bone_Marrow_VertebralBody_SS2_B133719_B134047, due to < 100 cells
# Skipped batch TSP6_Liver_NA_SS2_Blue_B133704, due to < 100 cells
# Skipped batch TSP2_Small_Intestine_Distal_SS2_B113712_B134443, due to < 100 cells
# Skipped batch TSP4_Muscle_Diaphragm_SS2_B114835_B134052, due to < 100 cells
# Skipped batch TSP6_Trachea_NA_SS2_Blue_B133897, due to < 100 cells
# Skipped batch TSP2_Bone_Marrow_VertebralBody_SS2_B113699_B133090, due to < 100 cells
# Skipped batch TSP5_Eye_Whole_SS2_B112809_B104877, due to < 100 cells
# Skipped batch TSP2_Muscle_Diaphragm_SS2_B114670_B133088, due to < 100 cells
# Skipped batch TSP3_Eye_LacrimalGland_SS2_B114698_B133920, due to < 100 cells
# Skipped batch TSP2_Large_Intestine_Proximal_SS2_B107308_B134451, due to < 100 cells
# Skipped batch TSP14_Tongue_Anterior_SS2_B134637_D101279, due to < 100 cells
# Skipped batch TSP14_Tongue_Anterior_SS2_B134630_D101277, due to < 100 cells
# Skipped batch TSP15_Eye_RPELimbus_SS2_B134494_B002628, due to < 100 cells
# Skipped batch TSP15_Eye_NA_SS2_B115075_B002620, due to < 100 cells
# Skipped batch TSP3_Eye_NoCornea_SS2_B114669_B133703, due to < 100 cells
# Skipped batch TSP3_Eye_NoCornea_SS2_B114664_B133905, due to < 100 cells
# Skipped batch TSP2_Lung_ProxMedialDistal_SS2_B113239_B111879, due to < 100 cells
# Skipped batch TSP8_Prostate_NA_SS2_B134141_B134697, due to < 100 cells
# Skipped batch TSP7_Tongue_Anterior_SS2_B134144_B133911, due to < 100 cells
# Skipped batch TSP14_Skin_Chest_SS2_B115070_D102106, due to < 100 cells
# Skipped batch TSP20_Stomach_Mucosa_SS2_D101998_B105391, due to < 100 cells
# Skipped batch TSP20_Stomach_Muscularis_SS2_D101984_B105389, due to < 100 cells
# Skipped batch TSP20_Stomach_Mucosa_SS2_B003838_B105388, due to < 100 cells
# Skipped batch TSP14_Skin_Abdomen_SS2_B134027_D102108, due to < 100 cells
# Skipped batch TSP3_Eye_LacrimalGland_SS2_B114696_B133903, due to < 100 cells
# Skipped batch TSP2_Small_Intestine_Proximal_SS2_B113702_B104867, due to < 100 cells
# Skipped batch TSP7_Tongue_Anterior_SS2_B134164_B133901, due to < 100 cells
# Skipped batch TSP14_Heart_NA_SS2_B134530_D101541, due to < 100 cells
# Skipped batch TSP10_Fat_MAT_SS2_B134181_B115064, due to < 100 cells
# Skipped batch TSP15_Eye_LacrimalCorneal_SS2_B115081_B002627, due to < 100 cells
# Skipped batch TSP14_Bladder_NA_SS2_B134607_D102098, due to < 100 cells
# Skipped batch TSP14_Muscle_RectusAbdominus_SS2_B134619_D101537, due to < 100 cells
# Skipped batch TSP6_Liver_NA_SS2_L144737_B114853, due to < 100 cells
# Skipped batch TSP6_Liver_NA_SS2_L144736_B133819, due to < 100 cells
# Skipped batch TSP6_Liver_NA_SS2_L144744_B133819, due to < 100 cells
# Skipped batch TSP30_Ovary_NA_SS2_TSPlate1_CZBG96582, due to < 100 cells
# Skipped batch TSP7_Blood_NA_SS2_B134151_B133701, due to < 100 cells
# Skipped batch TSP7_Tongue_Anterior_SS2_B134145_B133919, due to < 100 cells
# Skipped batch TSP6_Liver_NA_SS2_B113468_B133908, due to < 100 cells
# Skipped batch TSP4_Tongue_NA_SS2_B114837_B133733, due to < 100 cells
# Skipped batch TSP2_Large_Intestine_Proximal_SS2_B114618_B134450, due to < 100 cells
# Skipped batch TSP2_Skin_Chest_SS2_B113708_B111653, due to < 100 cells
# Skipped batch TSP2_Kidney_NA_SS2_B113455_B104861, due to < 100 cells
# Skipped batch TSP12_Heart_Ventricle_SS2_B133716_B134037, due to < 100 cells
# Skipped batch TSP12_Heart_Atria_SS2_B133721_B134036, due to < 100 cells
# Skipped batch TSP6_Liver_NA_SS2_L144735_B133819, due to < 100 cells
# Skipped batch TSP14_Liver_NA_SS2_B133708_D102105, due to < 100 cells
# Skipped batch TSP14_Thymus_NA_SS2_B134020_B002630, due to < 100 cells
# Skipped batch TSP14_Spleen_NA_SS2_B134611_D101282, due to < 100 cells
# Skipped batch TSP4_Mammary_NA_SS2_B114838_B104876, due to < 100 cells
# Skipped batch TSP21_Ear_Mesenchymal_10X_1_1, due to < 100 cells
# Skipped batch TSP27_Pancreas_exocrine_10X3primev31_1_1, due to < 100 cells
# Skipped batch TSP2_Skin_abdomen_10X_2_1, due to < 100 cells
# Skipped batch TSP27_Vasculature_CoronaryArteries_10X3primev31_1_1, due to < 100 cells
# Skipped batch TSP3_Eye_LacrimalGland_10X_1_1, due to < 100 cells
# Skipped batch TSP27_Vasculature_Aorta_10X3primev31_1_1, due to < 100 cells
# Skipped batch TSP25_Vasculature_CoronaryArteries_10X_2_1, due to < 100 cells
# Skipped batch TSP3_Eye_Orbital_10X_1_1, due to < 100 cells
# Skipped batch TSP2_Skin_abdomen_10X_1_1, due to < 100 cells
#               Rank-PCA  Corr-PCA  Corr-Weighted
# X_geneformer  0.138270  0.239081       0.063447
# X_scgpt       0.196729  0.305086       0.165880
# X_uce         0.220802  0.534173       0.330961

# %% [markdown]
# # Human Brain Cell Atlas

# %%
import scanpy as sc

# %%
from scgraph import scGraph

# Initialize the graph analyzer
scgraph = scGraph(
    adata_path="export_data/brain_atlas_uce_scgpt_geneformer.h5ad",   # Path to AnnData object
    batch_key="sample_id",                     # Column name for batch information
    label_key="cluster_id",                 # Column name for cell type labels
    trim_rate=0.05,                        # Trim rate for robust mean calculation
    thres_batch=100,                       # Minimum number of cells per batch
    thres_celltype=10,                    # Minimum number of cells per cell type
    only_umap=False,                        # Only evaluate 2D embeddings (mostly umaps)
)

# Run the analysis, return a pandas dataframe
results = scgraph.main()
display(results)
# Save the results
#results.to_csv("brain_atlas_results_sample.csv")
# Out:
# Processing batches, calcualte centroids and pairwise distances
#   0%|          | 0/606 [00:00<?, ?it/s]
# Skipped batch 10X176_4, due to < 100 cells
# Skipped batch 10X221_8, due to < 100 cells
# Skipped batch 10X176_6, due to < 100 cells
# Skipped batch 10X225_1, due to < 100 cells
# Skipped batch 10X222_4, due to < 100 cells
# Skipped batch 10X219_6, due to < 100 cells
# Skipped batch 10X222_3, due to < 100 cells
# Skipped batch 10X176_2, due to < 100 cells
# Skipped batch 10X361_2, due to < 100 cells
# Skipped batch 10X361_1, due to < 100 cells
# Skipped batch 10X176_1, due to < 100 cells
# Skipped batch 10X222_6, due to < 100 cells
# Skipped batch 10X219_5, due to < 100 cells
# Skipped batch 10X225_2, due to < 100 cells
# Skipped batch 10X175_8, due to < 100 cells
# Skipped batch 10X230_1, due to < 100 cells
# Skipped batch 10X219_2, due to < 100 cells
# Skipped batch 10X230_2, due to < 100 cells
# Skipped batch 10X388_7, due to < 100 cells
# Skipped batch 10X385_4, due to < 100 cells
# Skipped batch 10X389_7, due to < 100 cells
# Skipped batch 10X219_1, due to < 100 cells
# Skipped batch 10X222_5, due to < 100 cells
# Skipped batch 10X171_1, due to < 100 cells
# Skipped batch 10X176_3, due to < 100 cells
# Skipped batch 10X176_5, due to < 100 cells
# Skipped batch 10X222_8, due to < 100 cells
# Skipped batch 10X221_4, due to < 100 cells
# Skipped batch 10X221_3, due to < 100 cells
# Skipped batch 10X221_7, due to < 100 cells
# Skipped batch 10X224_1, due to < 100 cells
# Skipped batch 10X221_5, due to < 100 cells
# Skipped batch 10X230_5, due to < 100 cells
# Skipped batch 10X222_7, due to < 100 cells
# Skipped batch 10X224_2, due to < 100 cells
# Skipped batch 10X222_1, due to < 100 cells
# Skipped batch 10X222_2, due to < 100 cells
# Skipped batch 10X175_7, due to < 100 cells
# Skipped batch 10X236_1, due to < 100 cells
# Skipped batch 10X230_7, due to < 100 cells
# Skipped batch 10X220_8, due to < 100 cells
# Skipped batch 10X230_8, due to < 100 cells
# Skipped batch 10X237_3, due to < 100 cells
# Skipped batch 10X220_7, due to < 100 cells
# Skipped batch 10X230_6, due to < 100 cells
# Skipped batch 10X221_6, due to < 100 cells
#               Rank-PCA  Corr-PCA  Corr-Weighted
# X_geneformer  0.209621  0.210178       0.246759
# X_scGPT       0.474675  0.528535       0.570297
# X_uce         0.564300  0.652205       0.673384
